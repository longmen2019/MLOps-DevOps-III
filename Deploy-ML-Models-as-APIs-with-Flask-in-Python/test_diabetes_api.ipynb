# %%
# !pip install requests==2.32.3

# %%
import requests

# %%
url = "http://127.0.0.1:5000/predict"

# %%
sample_data = {
    "Pregnancies": 3,                  # usually 0–17
    "Glucose": 145,                     # typically 70–200 mg/dL
    "BloodPressure": 82,                # usually 50–120 mmHg
    "SkinThickness": 28,                # usually 10–50 mm
    "Insulin": 130,                     # typically 15–276 μU/ml
    "BMI": 32.5,                        # usually 18–50 kg/m^2
    "DiabetesPedigreeFunction": 0.45,   # usually 0.1–2.5
    "Age": 41                           # usually 21–81 years
}

# %%
response = requests.post(url, json=sample_data)
print(response.json())
# Out:
# {'prediction': 'No Diabetes'}
